# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime
# %matplotlib inline

# %%
os.chdir("CRE Data")

# %%
dftarget=pd.read_excel("targetfull v2.xlsx")

# %%
dftarget
# Out:
#              DATE                                 CUST_NAME  FACILITY_NUM  \
# 33237  2005-03-31                          "CORAM DEO, LLC"  1.592124e+19
# 135959 2005-03-31           RANCHO MONTEREY LTD PARTNERSHIP  7.257413e+19
# 135966 2005-03-31                    RANCHO PARK ASSOCIATES  7.257458e+19
# 83194  2005-03-31                         RANDALL E KESSLER  5.061000e+19
# 65107  2005-03-31                          RANDELL S HANSEN  3.455089e+19
# 66846  2005-03-31                           RANDHIR S HAYER  3.545888e+19
# 45409  2005-03-31                            EDEN GROUP LLC  2.425701e+19
# 184192 2005-03-31                       EDDIE KA KEUNG WONG  9.896967e+19
# 39877  2005-03-31                            RANDY J DENHAM  2.031515e+19
# 46181  2005-03-31                            RANDY S EIFLER  2.480701e+19
# 44419  2005-03-31                        EDD INVESTMENTS CO  2.387705e+19
# 115170 2005-03-31                          RAPHAEL N NISSIM  6.579286e+19
# ...

# %%
dftarget['DowngradeMax'].value_counts()
# Out:
# 0    189600
# 1      6205
# Name: DowngradeMax, dtype: int64

# %%
dftarget['UpgradeMax'].value_counts()
# Out:
# 0    190118
# 1      5687
# Name: UpgradeMax, dtype: int64

# %%
dftarget['RE_RISK_PROPERTY_TYPE'].value_counts()
# Out:
# APARTMENT                    81787
# INDUSTRIAL                   36348
# RETAIL                       25705
# OFFICE                       22418
# NON-RES INCOME               10734
# OTHER                         4691
# UNSECURED                     4556
# SFR                           3202
# OTHER REAL ESTATE SECURED     1407
# LAND                          1261
# FOR SALE                      1113
# UNCATEGORIZED                  829
# SECURED - NON RE               210
# OTHER REAL ESTATE               16
# UNKNOWN                          5
# Name: RE_RISK_PROPERTY_TYPE, dtype: int64

# %%
os.chdir("..")

# %%
os.chdir("Updated Material")

# %%
dfMarket=pd.read_excel("dfVariable2WidedfDate.xlsx")

# %%
dfMarket
# Out:
#             Date Geography_Code Geography_Name Property_Code Property_Name  \
# 0     1982-03-31          ATLNA        Atlanta          APT0     Apartment
# 1     1982-03-31          ATLNA        Atlanta          IND0    Industrial
# 2     1982-03-31          ATLNA        Atlanta          OFC0        Office
# 3     1982-03-31          ATLNA        Atlanta          RET0        Retail
# 4     1982-03-31          BOSTN         Boston          APT0     Apartment
# 5     1982-03-31          BOSTN         Boston          HOT0         Hotel
# 6     1982-03-31          BOSTN         Boston          IND0    Industrial
# 7     1982-03-31          BOSTN         Boston          OFC0        Office
# 8     1982-03-31          BOSTN         Boston          OWN0      For-Sale
# 9     1982-03-31          BOSTN         Boston          RET0        Retail
# 10    1982-03-31          CHICG        Chicago          APT0     Apartment
# ...

# %%
dfMarket['Geography_Name'].value_counts()
# Out:
# Los Angeles      882
# Washington       882
# Boston           882
# United States    882
# San Jose         735
# New York         735
# Seattle          735
# Chicago          735
# San Francisco    735
# San Diego        735
# Dallas           588
# Orange County    588
# Atlanta          588
# Inland Empire    294
# Miami            147
# Philadelphia     147
# Denver           147
# Phoenix          147
# Name: Geography_Name, dtype: int64

# %%
dfMarket['Property_Name'].value_counts()
# Out:
# Retail        1911
# Apartment     1911
# Office        1911
# Industrial    1911
# For-Sale      1764
# Hotel         1176
# Name: Property_Name, dtype: int64

# %%
dfMarketUS=dfMarket.loc[dfMarket['Geography_Name']=='United States',:]

# %%
dfMarketUS
# Out:
#             Date Geography_Code Geography_Name Property_Code Property_Name  \
# 60    1982-03-31          USTOT  United States          APT0     Apartment
# 61    1982-03-31          USTOT  United States          HOT0         Hotel
# 62    1982-03-31          USTOT  United States          IND0    Industrial
# 63    1982-03-31          USTOT  United States          OFC0        Office
# 64    1982-03-31          USTOT  United States          OWN0      For-Sale
# 65    1982-03-31          USTOT  United States          RET0        Retail
# 132   1982-06-30          USTOT  United States          APT0     Apartment
# 133   1982-06-30          USTOT  United States          HOT0         Hotel
# 134   1982-06-30          USTOT  United States          IND0    Industrial
# 135   1982-06-30          USTOT  United States          OFC0        Office
# 136   1982-06-30          USTOT  United States          OWN0      For-Sale
# ...

# %%
dfMarketUS.replace({'Retail':'RETAIL','Industrial':'INDUSTRIAL','Apartment':'APARTMENT','Office':'OFFICE','For-Sale':'FOR SALE','Hotel':'HOTEL'},inplace=True)
# Out:
# C:\Users\ru89110\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3795: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
dfMarketUS
# Out:
#             Date Geography_Code Geography_Name Property_Code Property_Name  \
# 60    1982-03-31          USTOT  United States          APT0     APARTMENT
# 61    1982-03-31          USTOT  United States          HOT0         HOTEL
# 62    1982-03-31          USTOT  United States          IND0    INDUSTRIAL
# 63    1982-03-31          USTOT  United States          OFC0        OFFICE
# 64    1982-03-31          USTOT  United States          OWN0      FOR SALE
# 65    1982-03-31          USTOT  United States          RET0        RETAIL
# 132   1982-06-30          USTOT  United States          APT0     APARTMENT
# 133   1982-06-30          USTOT  United States          HOT0         HOTEL
# 134   1982-06-30          USTOT  United States          IND0    INDUSTRIAL
# 135   1982-06-30          USTOT  United States          OFC0        OFFICE
# 136   1982-06-30          USTOT  United States          OWN0      FOR SALE
# ...

# %%
TargetMarket=pd.merge(dftarget,dfMarketUS,how='left',left_on=['DATE','RE_RISK_PROPERTY_TYPE'],right_on=['Date','Property_Name'])

# %%
TargetMarket
# Out:
#              DATE                                 CUST_NAME  FACILITY_NUM  \
# 0      2005-03-31                          "CORAM DEO, LLC"  1.592124e+19
# 1      2005-03-31           RANCHO MONTEREY LTD PARTNERSHIP  7.257413e+19
# 2      2005-03-31                    RANCHO PARK ASSOCIATES  7.257458e+19
# 3      2005-03-31                         RANDALL E KESSLER  5.061000e+19
# 4      2005-03-31                          RANDELL S HANSEN  3.455089e+19
# 5      2005-03-31                           RANDHIR S HAYER  3.545888e+19
# 6      2005-03-31                            EDEN GROUP LLC  2.425701e+19
# 7      2005-03-31                       EDDIE KA KEUNG WONG  9.896967e+19
# 8      2005-03-31                            RANDY J DENHAM  2.031515e+19
# 9      2005-03-31                            RANDY S EIFLER  2.480701e+19
# 10     2005-03-31                        EDD INVESTMENTS CO  2.387705e+19
# 11     2005-03-31                          RAPHAEL N NISSIM  6.579286e+19
# ...

# %%
TargetMarket.to_excel('TargetMarket.xlsx')

# %%
## Target data without market variables  
## NON-RES INCOME               10734
## OTHER                         4691
## UNSECURED                     4556
## SFR                           3202
## OTHER REAL ESTATE SECURED     1407
## LAND                          1261
## UNCATEGORIZED                  829
## SECURED - NON RE               210
## OTHER REAL ESTATE               16
## UNKNOWN                          5
## no type

# %%
Markets=['ATLANTA'....]

# %%
dftargetIndustrial= dftarget.loc[dftarget['RE_RISK_PROPERTY_TYPE']=='INDUSTRIAL',:]

# %%
dftargetIndustrial
# Out:
#              DATE                                 CUST_NAME  FACILITY_NUM  \
# 33237  2005-03-31                          "CORAM DEO, LLC"  1.592124e+19
# 46181  2005-03-31                            RANDY S EIFLER  2.480701e+19
# 115170 2005-03-31                          RAPHAEL N NISSIM  6.579286e+19
# 136635 2005-03-31                      RAUDMAN LIVING TRUST  7.271093e+19
# 182306 2005-03-31                      WILBUR-PARTHENIA LLC  9.798985e+19
# 45157  2005-03-31                  EASTSHORE PROPERTIES LLC  2.404117e+19
# 45147  2005-03-31                  EASTSHORE PROPERTIES LLC  2.404117e+19
# 156087 2005-03-31                      RAYMOND ADRIAN SMITH  8.446200e+19
# 44956  2005-03-31               EASTGATE MIRAMAR ASSOCIATES  2.404116e+19
# 44924  2005-03-31               EASTGATE MIRAMAR ASSOCIATES  2.404116e+19
# 44897  2005-03-31                  EASTGATE MEDIA GROUP LLC  2.404115e+19
# 182263 2005-03-31                    WIDDES REVOCABLE TRUST  9.782619e+19
# ...

# %%
dftargetIndustrialcustomer=dftargetIndustrial.groupby(['DATE'])['CUST_NAME'].agg(['count'])

# %%
dftargetIndustrialDowngrade=dftargetIndustrial.groupby(['DATE'])['DowngradeMax'].agg(['mean'])

# %%
dftargetIndustrialUpgrade=dftargetIndustrial.groupby(['DATE'])['UpgradeMax'].agg(['mean'])

# %%
dftargetIndustrialcustomer
# Out:
#             count
# DATE
# 2005-03-31    967
# 2005-06-30    955
# 2005-09-30    949
# 2005-12-31   1078
# 2006-03-31   1049
# 2006-06-30   1057
# 2006-09-30   1053
# 2006-12-31   1053
# 2007-03-31   1045
# 2007-06-30   1030
# 2007-09-30   1023
# 2007-12-31   1016
# 2008-03-31    999
# 2008-06-30    997
# 2008-09-30    994
# 2008-12-31    974
# 2009-03-31    951
# 2009-06-30    936
# 2009-09-30    907
# 2009-12-31    886
# 2010-03-31    872
# 2010-06-30    861
# 2010-09-30    581
# 2010-12-31    536
# 2011-03-31    526
# 2011-06-30    528
# 2011-09-30    516
# 2011-12-31    509
# 2012-03-31    499
# 2012-06-30    461
# 2012-09-30    421
# 2012-12-31    344
# 2013-03-31    297
# 2013-06-30    388
# 2013-09-30    392
# 2013-12-31    381
# 2014-03-31    379
# 2014-06-30    406
# 2014-09-30    434
# 2014-12-31    484
# 2015-03-31    502
# 2015-06-30    518
# 2015-09-30    534
# 2015-12-31    545
# 2016-03-31    568
# 2016-06-30    565
# 2016-09-30    572
# 2016-12-31    571
# ...

# %%
dftargetIndustrialDowngrade
# Out:
#                 mean
# DATE
# 2005-03-31  0.000000
# 2005-06-30  0.012565
# 2005-09-30  0.012645
# 2005-12-31  0.011132
# 2006-03-31  0.014299
# 2006-06-30  0.015137
# 2006-09-30  0.007597
# 2006-12-31  0.014245
# 2007-03-31  0.013397
# 2007-06-30  0.014563
# 2007-09-30  0.015640
# 2007-12-31  0.017717
# 2008-03-31  0.024024
# 2008-06-30  0.025075
# 2008-09-30  0.024145
# 2008-12-31  0.042094
# 2009-03-31  0.063091
# 2009-06-30  0.075855
# 2009-09-30  0.056229
# 2009-12-31  0.038375
# 2010-03-31  0.045872
# 2010-06-30  0.082462
# 2010-09-30  0.049914
# 2010-12-31  0.037313
# 2011-03-31  0.030418
# 2011-06-30  0.043561
# 2011-09-30  0.052326
# 2011-12-31  0.062868
# 2012-03-31  0.040080
# 2012-06-30  0.056399
# 2012-09-30  0.045131
# 2012-12-31  0.034884
# 2013-03-31  0.026936
# 2013-06-30  0.046392
# 2013-09-30  0.068878
# 2013-12-31  0.057743
# 2014-03-31  0.021108
# 2014-06-30  0.036946
# 2014-09-30  0.036866
# 2014-12-31  0.039256
# 2015-03-31  0.031873
# 2015-06-30  0.042471
# ...

# %%
dftargetIndustrialUpgrade
# Out:
#                 mean
# DATE
# 2005-03-31  0.000000
# 2005-06-30  0.015707
# 2005-09-30  0.021075
# 2005-12-31  0.016698
# 2006-03-31  0.013346
# 2006-06-30  0.011353
# 2006-09-30  0.013295
# 2006-12-31  0.024691
# 2007-03-31  0.008612
# 2007-06-30  0.018447
# 2007-09-30  0.009775
# 2007-12-31  0.010827
# 2008-03-31  0.003003
# 2008-06-30  0.013039
# 2008-09-30  0.014085
# 2008-12-31  0.009240
# 2009-03-31  0.002103
# 2009-06-30  0.003205
# 2009-09-30  0.009923
# 2009-12-31  0.012415
# 2010-03-31  0.021789
# 2010-06-30  0.040650
# 2010-09-30  0.029260
# 2010-12-31  0.039179
# 2011-03-31  0.032319
# 2011-06-30  0.051136
# 2011-09-30  0.042636
# 2011-12-31  0.064833
# 2012-03-31  0.038076
# 2012-06-30  0.058568
# 2012-09-30  0.042755
# 2012-12-31  0.029070
# 2013-03-31  0.043771
# 2013-06-30  0.054124
# 2013-09-30  0.056122
# 2013-12-31  0.065617
# 2014-03-31  0.052770
# 2014-06-30  0.054187
# 2014-09-30  0.039171
# 2014-12-31  0.039256
# 2015-03-31  0.025896
# 2015-06-30  0.059846
# ...

# %%
dftargetApartment= dftarget.loc[dftarget['RE_RISK_PROPERTY_TYPE']=='APARTMENT',:]

# %%
dftargetaPARTMENTcustomer=dftargetApartment.groupby(['DATE'])['CUST_NAME'].agg(['count'])

# %%
dftargetApartmentDowngrade=dftargetApartment.groupby(['DATE'])['DowngradeMax'].agg(['mean'])

# %%
dftargetApartmentUpgrade=dftargetApartment.groupby(['DATE'])['UpgradeMax'].agg(['mean'])

# %%
dftargetaPARTMENTcustomer
# Out:
#             count
# DATE
# 2005-03-31    314
# 2005-06-30    311
# 2005-09-30    302
# 2005-12-31   1654
# 2006-03-31   1670
# 2006-06-30   1666
# 2006-09-30   1688
# 2006-12-31   1713
# 2007-03-31   1749
# 2007-06-30   1825
# 2007-09-30   1849
# 2007-12-31   1927
# 2008-03-31   1996
# 2008-06-30   2057
# 2008-09-30   2074
# 2008-12-31   2123
# 2009-03-31   2125
# 2009-06-30   2087
# 2009-09-30   2038
# 2009-12-31   2037
# 2010-03-31   2024
# 2010-06-30   2012
# 2010-09-30    870
# 2010-12-31    884
# 2011-03-31    912
# 2011-06-30    947
# 2011-09-30   1016
# 2011-12-31   1088
# 2012-03-31   1142
# 2012-06-30   1131
# 2012-09-30   1176
# 2012-12-31   1221
# 2013-03-31   1221
# 2013-06-30   1598
# 2013-09-30   1643
# 2013-12-31   1692
# 2014-03-31   1719
# 2014-06-30   1720
# 2014-09-30   1737
# 2014-12-31   1752
# 2015-03-31   1757
# 2015-06-30   1755
# 2015-09-30   1762
# 2015-12-31   1764
# 2016-03-31   1796
# 2016-06-30   1803
# 2016-09-30   1789
# 2016-12-31   1779
# ...

# %%
dftargetApartmentUpgrade
# Out:
#                 mean
# DATE
# 2005-03-31  0.000000
# 2005-06-30  0.000000
# 2005-09-30  0.013245
# 2005-12-31  0.002418
# 2006-03-31  0.001198
# 2006-06-30  0.003001
# 2006-09-30  0.002962
# 2006-12-31  0.002335
# 2007-03-31  0.000572
# 2007-06-30  0.002740
# 2007-09-30  0.004867
# 2007-12-31  0.004152
# 2008-03-31  0.001002
# 2008-06-30  0.002917
# 2008-09-30  0.000964
# 2008-12-31  0.000942
# 2009-03-31  0.002824
# 2009-06-30  0.002396
# 2009-09-30  0.007360
# 2009-12-31  0.005891
# 2010-03-31  0.035079
# 2010-06-30  0.063618
# 2010-09-30  0.065517
# 2010-12-31  0.049774
# 2011-03-31  0.017544
# 2011-06-30  0.034847
# 2011-09-30  0.029528
# 2011-12-31  0.024816
# 2012-03-31  0.053415
# 2012-06-30  0.056587
# 2012-09-30  0.045918
# 2012-12-31  0.067977
# 2013-03-31  0.071253
# 2013-06-30  0.057572
# 2013-09-30  0.055995
# 2013-12-31  0.072695
# 2014-03-31  0.041885
# 2014-06-30  0.066860
# 2014-09-30  0.054116
# 2014-12-31  0.039384
# 2015-03-31  0.042686
# 2015-06-30  0.051852
# ...

# %%
dftargetRETAIL= dftarget.loc[dftarget['RE_RISK_PROPERTY_TYPE']=='RETAIL',:]

# %%
dftargetRETAILcustomer=dftargetRETAIL.groupby(['DATE'])['CUST_NAME'].agg(['count'])

# %%
dftargetRETAILDowngrade=dftargetRETAIL.groupby(['DATE'])['DowngradeMax'].agg(['mean'])

# %%
dftargetRETAILUpgrade=dftargetRETAIL.groupby(['DATE'])['UpgradeMax'].agg(['mean'])

# %%
dftargetRETAILUpgrade
# Out:
#                 mean
# DATE
# 2005-03-31  0.000000
# 2005-06-30  0.007371
# 2005-09-30  0.020253
# 2005-12-31  0.013006
# 2006-03-31  0.000000
# 2006-06-30  0.004354
# 2006-09-30  0.007123
# 2006-12-31  0.004274
# 2007-03-31  0.005839
# 2007-06-30  0.007215
# 2007-09-30  0.008621
# 2007-12-31  0.012535
# 2008-03-31  0.001381
# 2008-06-30  0.005626
# 2008-09-30  0.007225
# 2008-12-31  0.002950
# 2009-03-31  0.002954
# 2009-06-30  0.003017
# 2009-09-30  0.006182
# 2009-12-31  0.009600
# 2010-03-31  0.042208
# 2010-06-30  0.057377
# 2010-09-30  0.065868
# 2010-12-31  0.030675
# 2011-03-31  0.024922
# 2011-06-30  0.044025
# 2011-09-30  0.038339
# 2011-12-31  0.049669
# 2012-03-31  0.064626
# 2012-06-30  0.089928
# 2012-09-30  0.060932
# 2012-12-31  0.025455
# 2013-03-31  0.062731
# 2013-06-30  0.030905
# 2013-09-30  0.079430
# 2013-12-31  0.058824
# 2014-03-31  0.050000
# 2014-06-30  0.040268
# 2014-09-30  0.056180
# 2014-12-31  0.062500
# 2015-03-31  0.038636
# 2015-06-30  0.063205
# ...

# %%
dftargetOFFICE= dftarget.loc[dftarget['RE_RISK_PROPERTY_TYPE']=='OFFICE',:]

# %%
dftargetOFFICEcustomer=dftargetOFFICE.groupby(['DATE'])['CUST_NAME'].agg(['count'])

# %%
dftargetOFFICEDowngrade=dftargetOFFICE.groupby(['DATE'])['DowngradeMax'].agg(['mean'])

# %%
dftargetOFFICEUpgrade=dftargetOFFICE.groupby(['DATE'])['UpgradeMax'].agg(['mean'])

# %%
dftargetOFFICEUpgrade
# Out:
#                 mean
# DATE
# 2005-03-31  0.000000
# 2005-06-30  0.013283
# 2005-09-30  0.011516
# 2005-12-31  0.013534
# 2006-03-31  0.001531
# 2006-06-30  0.018576
# 2006-09-30  0.010853
# 2006-12-31  0.004601
# 2007-03-31  0.012308
# 2007-06-30  0.010870
# 2007-09-30  0.003140
# 2007-12-31  0.006349
# 2008-03-31  0.006289
# 2008-06-30  0.012559
# 2008-09-30  0.004831
# 2008-12-31  0.003273
# 2009-03-31  0.005034
# 2009-06-30  0.006908
# 2009-09-30  0.001786
# 2009-12-31  0.012774
# 2010-03-31  0.030476
# 2010-06-30  0.039848
# 2010-09-30  0.059190
# 2010-12-31  0.040268
# 2011-03-31  0.038062
# 2011-06-30  0.046099
# 2011-09-30  0.049470
# 2011-12-31  0.042403
# 2012-03-31  0.050179
# 2012-06-30  0.048193
# 2012-09-30  0.031250
# 2012-12-31  0.050000
# 2013-03-31  0.048128
# 2013-06-30  0.055556
# 2013-09-30  0.073955
# 2013-12-31  0.063123
# 2014-03-31  0.030928
# 2014-06-30  0.055556
# 2014-09-30  0.066038
# 2014-12-31  0.038585
# 2015-03-31  0.049080
# 2015-06-30  0.065089
# ...

# %%
dftargetForSale= dftarget.loc[dftarget['RE_RISK_PROPERTY_TYPE']=='FOR SALE',:]

# %%
dftargetForSalecustomer=dftargetForSale.groupby(['DATE'])['CUST_NAME'].agg(['count'])

# %%
dftargetForSaleDowngrade=dftargetForSale.groupby(['DATE'])['DowngradeMax'].agg(['mean'])

# %%
dftargetForSaleUpgrade=dftargetForSale.groupby(['DATE'])['UpgradeMax'].agg(['mean'])

# %%
dftargetForSalecustomer
# Out:
#             count
# DATE
# 2013-06-30      4
# 2013-09-30    143
# 2013-12-31    125
# 2014-03-31    106
# 2014-06-30     83
# 2014-09-30     60
# 2014-12-31     58
# 2015-03-31     57
# 2015-06-30     54
# 2015-09-30     51
# 2015-12-31     53
# 2016-03-31     51
# 2016-06-30     52
# 2016-09-30     43
# 2016-12-31     39
# 2017-03-31     38
# 2017-06-30     36
# 2017-09-30     30
# 2017-12-31     30

# %%
dftargetForSaleUpgrade
# Out:
#                 mean
# DATE
# 2013-06-30  0.000000
# 2013-09-30  0.027972
# 2013-12-31  0.040000
# 2014-03-31  0.028302
# 2014-06-30  0.084337
# 2014-09-30  0.016667
# 2014-12-31  0.051724
# 2015-03-31  0.052632
# 2015-06-30  0.018519
# 2015-09-30  0.098039
# 2015-12-31  0.037736
# 2016-03-31  0.039216
# 2016-06-30  0.038462
# 2016-09-30  0.023256
# 2016-12-31  0.076923
# 2017-03-31  0.026316
# 2017-06-30  0.166667
# 2017-09-30  0.066667
# 2017-12-31  0.100000

# %% [markdown]
# #### Analysis on market Variables

# %%
### information gain
