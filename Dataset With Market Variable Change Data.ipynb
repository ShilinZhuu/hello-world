# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime
# %matplotlib inline

# %%
# %pwd
# Out:
# 'C:\\Users\\ru89110\\Documents\\PWG EW'

# %%
os.chdir("10.1")

# %%
df=pd.read_excel("CombinedFile_201810_.xlsx")

# %%
diffSPImpliedBTMU=pd.read_excel("diffSPImpliedBTMU.xlsx")
diffMoodysImpliedBTMU=pd.read_excel("diffMoodysImpliedBTMU.xlsx")
diffEDFImpliedBTMU=pd.read_excel("diffEDFImpliedBTMU.xlsx")
diffCDSImpliedBTMU=pd.read_excel("diffCDSImpliedBTMU.xlsx")
C55DiffDf=pd.read_excel("C55DiffDf.xlsx")

# %%
data1=pd.merge(C55DiffDf,diffSPImpliedBTMU[['Index_Col','Comparison']],on='Index_Col',how='left')

# %%
data1.rename(columns={'Comparison':'SP_Change'},inplace=True)

# %%
data2=pd.merge(data1,diffMoodysImpliedBTMU[['Index_Col','Comparison']],on='Index_Col',how='left')

# %%
data2.rename(columns={'Comparison':'Moodys_Change'},inplace=True)

# %%
data3=pd.merge(data2,diffEDFImpliedBTMU[['Index_Col','Comparison']],on='Index_Col',how='left')

# %%
data3.rename(columns={'Comparison':'EDF_Change'},inplace=True)

# %%
data4=pd.merge(data3,diffCDSImpliedBTMU[['Index_Col','Comparison']],on='Index_Col',how='left')

# %%
data4.rename(columns={'Comparison':'CDS_Change'},inplace=True)

# %%
data4.to_excel('data4withChanges.xlsx', index  = True)

# %%
# Out:
#       Index_Col As of Date  BTM Borrower Rtg  BTM Rating  Dowgrade   \
# 0         32768 2017-11-30                52         5.2          1
# 1         32771 2018-02-28                52         5.2          0
# 2        131076 2017-07-31                33         3.3          0
# 3         32773 2018-04-30                52         5.2          0
# 4         32774 2018-05-31                52         5.2          0
# 5         98313 2017-10-31                32         3.2          0
# 6         32778 2018-02-28                52         5.2          0
# 7         98317 2018-02-28                31         3.1          0
# 8        131085 2018-04-30                33         3.3          0
# 9         32783 2018-02-28                61         6.1          0
# 10        32784 2018-03-30                61         6.1          0
# 11       131086 2018-05-31                33         3.3          0
# 12        32795 2017-11-30                52         5.2          0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=154952, step=1)
