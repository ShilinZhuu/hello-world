# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime
# %matplotlib inline

# %%
df=pd.read_excel("overalltv.xlsx")

# %%
df  ###adding in the ppt: the aggregation method for the variables in the df

# %%
list(df.columns)
# Out:
# ['Date',
#  'Downgrade intensity ',
#  'Unnamed: 2',
#  '1+ Unit Permitting',
#  '1+ Unit Starts',
#  '2+ Unit Permitting',
#  '2+ Unit Starts',
#  'Cap Rate Spread',
#  'Census Vacancy Rate',
#  'Const. Deliv. (Bil. 09 $)',
#  'Const. Deliv. (Thous. SF)',
#  'Employ. Growth',
#  'Excess Return',
#  'Home Sales',
#  'House Price to Income',
#  'IP Growth',
#  'Inst. Vacancy Rate',
#  'Leis. Emp. Growth',
#  'MPF Vacancy Rate',
#  'Mall Rent Growth',
#  'Mfg. Emp. Growth',
#  'Mortgage Debt Growth',
#  'Occupancy Rate',
#  'Ofc. Employ. Growth',
#  'Permit Valuation',
#  'Power Rent Growth',
#  'Price Growth',
#  'Rent Growth',
#  'Res. Invest. Share of GDP',
#  'Retail Sales Growth',
#  'RevPar Growth',
#  'Strip Rent Growth',
#  'Trade Emp. Growth',
#  'Trans. Emp. Growth',
#  'Trans. Vol. (Bil. $)',
#  'Vacancy Rate']

# %%
df.shape
# Out:
# (52, 36)

# %%
df.columns[2:]
# Out:
# Index(['Unnamed: 2', '1+ Unit Permitting', '1+ Unit Starts',
#        '2+ Unit Permitting', '2+ Unit Starts', 'Cap Rate Spread',
#        'Census Vacancy Rate', 'Const. Deliv. (Bil. 09 $)',
#        'Const. Deliv. (Thous. SF)', 'Employ. Growth', 'Excess Return',
#        'Home Sales', 'House Price to Income', 'IP Growth',
#        'Inst. Vacancy Rate', 'Leis. Emp. Growth', 'MPF Vacancy Rate',
#        'Mall Rent Growth', 'Mfg. Emp. Growth', 'Mortgage Debt Growth',
#        'Occupancy Rate', 'Ofc. Employ. Growth', 'Permit Valuation',
#        'Power Rent Growth', 'Price Growth', 'Rent Growth',
#        'Res. Invest. Share of GDP', 'Retail Sales Growth', 'RevPar Growth',
#        'Strip Rent Growth', 'Trade Emp. Growth', 'Trans. Emp. Growth',
#        'Trans. Vol. (Bil. $)', 'Vacancy Rate'],
#       dtype='object')

# %%
#df['Unnamed: 2_lag'] =df['Unnamed: 2'].shift(1)   ##create lag one. the current datapoint represent the previous date's data value

#concatenetion put two strings together
#str() built-in python

# %%
##Create lags for all exsisting variables
for i in df.columns[2:]:
    df[i+'_lag'] = df[i].shift(1)

# %%
df=df.set_index('Date')

# %%
df
# Out:
#             Downgrade intensity   Unnamed: 2  1+ Unit Permitting  \
# Date
growthRate=['Employ. Growth','IP Growth','Leis. Emp. Growth','Mall Rent Growth','Mfg. Emp. Growth','Mortgage Debt Growth','Ofc. Employ. Growth','Power Rent Growth''Price Growth','Rent Growth','Retail Sales Growth','RevPar Growth','Strip Rent Growth', 'Trade Emp. Growth', 'Trans. Emp. Growth']
other=['Const. Deliv. (Bil. 09 $)', 'Const. Deliv. (Thous. SF)','Home Sales','Permit Valuation','Trans. Vol. (Bil. $)']

# %%
oriVariable[units].hist()

# %%
## see the distribution of the variables 
oriVariable.hist()
plt.figure(figsize=(1,1))
plt.show()

# %%
## Time Series Plot for all Variables
for i in oriVariable.columns:
    oriVariable[i].plot()

# %%
YOY=(oriVariable-oriVariable.shift(1))/oriVariable    ##yoy transformation

# %%
  ##log transformation

# %%
oriVariable
# Out:
#             Unnamed: 2  1+ Unit Permitting  1+ Unit Starts  \
# Date
# 2005-03-31    0.000000         5087.454545           448.2
# 2005-06-30   -0.001402         6580.090909           575.3
# 2005-09-30   -0.007092         5870.454545           567.5
# 2005-12-31   -0.001024         4918.272727           477.1
# 2006-03-31    0.001653         5249.636364           464.0
# 2006-06-30    0.000620         5823.181818           520.9
# 2006-09-30    0.002664         4595.818182           457.8
# 2006-12-31    0.004881         3785.181818           358.2
# 2007-03-31    0.004672         3992.272727           321.9
# 2007-06-30    0.004427         4314.000000           409.9
# 2007-09-30    0.005027         3649.363636           350.6
# 2007-12-31    0.013236         3140.000000           272.7
# 2008-03-31    0.036776         2397.363636           231.4
# 2008-06-30    0.021815         4788.818182           283.7
# 2008-09-30    0.019823         1871.090909           237.0
# ...

# %%
oriVariable.apply(np.log)  ##log trnsformation
# Out:
#             1+ Unit Permitting  1+ Unit Starts  2+ Unit Permitting  \
# Date
# 2005-03-31            8.534533        6.105240            7.760716
# 2005-06-30            8.791804        6.354892            7.999818
# 2005-09-30            8.677687        6.341241            7.952205
# 2005-12-31            8.500713        6.167726            7.806900
# 2006-03-31            8.565914        6.139885            7.995840
# 2006-06-30            8.669602        6.255558            8.035333
# 2006-09-30            8.432902        6.126432            7.939901
# 2006-12-31            8.238849        5.881091            7.819268
# 2007-03-31            8.292116        5.774241            7.949209
# 2007-06-30            8.369621        6.015913            7.961457
# 2007-09-30            8.202308        5.859646            7.859960
# 2007-12-31            8.051978        5.608372            7.876322
# 2008-03-31            7.782125        5.444148            7.618210
# ...

# %%
##correlation analysis on original variables and transformed variables

# %%
from sklearn import preprocessing

# %%
#standardization

# %%
#print value distribution

# %%
a=df['data']

# %%
a

# %%
std=StandardScaler()

# %%
oriVariable_std=std.fit_transform(df)
