# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime
# %matplotlib inline

# %%
df=pd.read_excel("CombinedFile_201810_.xlsx")

# %%
df.columns
# Out:
# Index(['As of Date', 'BTM Borrower Rtg', 'BTM Rating', 'Dowgrade ',
#        'Downgrade Notch', 'CDL Customer ID', 'Cust Regist Nm', 'Division',
#        'Exposure', 'EDF Implied BTMU Rating', 'EDF Notch', 'EDF Value',
#        'Notch Diff EDF Implied vs BTMU', 'Secondary Loan Avg Price',
#        'CDS Implied BTMU Rating', 'CDS Spread (5yr)',
#        'Notch Diff CDS Implied vs BTMU', 'Moodys Implied BTMU Rating',
#        'Moodys LT Rating', 'Notch Diff Moodys Implied vs BTMU',
#        'S&P Implied BTMU Rating', 'S&P LT Rating', 'Moody's Id', 'BIR'],
#       dtype='object')

# %%
df
# Out:
#        As of Date  BTM Borrower Rtg  BTM Rating  Dowgrade   Downgrade Notch  \
# 0      2014-09-30                 4         4.0          0              0.0
# 1      2014-10-31                 4         4.0          0              0.0
# 2      2014-11-28                 4         4.0          0              0.0
# 3      2014-12-31                 4         4.0          0              0.0
# 4      2015-01-30                 4         4.0          0              0.0
# 5      2015-02-27                 4         4.0          0              0.0
# 6      2015-03-31                 4         4.0          0              0.0
# 7      2015-04-30                 4         4.0          0              0.0
# 8      2015-05-29                 4         4.0          0              0.0
# 9      2015-06-30                 4         4.0          0              0.0
# 10     2015-07-31                 4         4.0          0              0.0
# ...

# %%
df['Downgrade Notch'].unique()
# Out:
# array([0. , 1. , 1.2, 1.1, 0.8, 0.1, 0.1, 0.9, 0.9, 0.2, 0.1, 1.9, 0.8,
#        1.2, 3. , 1.9, 2.1, 0.7, 5.1, 3.1, 2. , 3.2, 4.7, 1.1, 2.2, 0.1,
#        0.8, 1.8, 1.1, 4.1, 4. , 6. , 0.9, 4.9, 0.2, 7. , 6.2, 5.2, 2.8,
#        6.2, 8.1, 2.9, 2.9, 3.3, 3.8, 0.3, 4.2, 6.9, 0.7, 3. , 5.9, 0.2,
#        2. , 4.8, 7.9, 1.3, 3.1, 5. , 3.8, 3.9, 3.7])

# %%
a=pd.DataFrame(df['Downgrade Notch'].value_counts(dropna=False))

# %%
# %pwd
# Out:
# 'C:\\Users\\ru89110\\Documents\\PWG EW\\10.1'

# %%
a.to_excel('DN counts.xlsx', index  = True)

# %%
a.sort_values('Downgrade Notch')
# Out:
#      Downgrade Notch
# 6.2                1
# 0.7                1
# 6.0                1
# 8.1                1
# 3.8                1
# 3.3                1
# 3.9                1
# 4.8                1
# 5.0                1
# 1.3                1
# 0.2                1
# 6.2                1
# 6.9                2
# 3.0                2
# 2.9                2
# 4.9                2
# 3.1                2
# 7.0                2
# 7.9                2
# 2.0                2
# 3.7                2
# 0.1                3
# 4.7                3
# 5.9                3
# 5.2                3
# 4.2                4
# 3.1                4
# 0.3                5
# 2.8                6
# 3.8                6
# ..               ...
# 5.1                8
# 4.1                9
# 1.1                9
# 2.9               13
# 0.2               14
# 0.8               18
# 1.1               21
# 4.0               23
# 2.2               24
# 0.9               25
# 0.2               28
# ...

# %% [markdown]
# ### distribution plot

# %%
dfUse=pd.read_excel("dfUse.xlsx")

# %%
dfUse
# Out:
#       Index_Col As of Date  BTM Borrower Rtg  BTM Rating  \
# 0            28 2017-01-31                 3         3.0
# 1            29 2017-02-28                 3         3.0
# 2            37 2017-10-31                 4         4.0
# 3           101 2015-12-31                81         8.1
# 4           103 2016-02-29                81         8.1
# 5           108 2016-09-30                 7         7.0
# 6           109 2016-10-31                 7         7.0
# 7           111 2017-01-31                 7         7.0
# 8           115 2017-06-30                 7         7.0
# 9           118 2017-09-29                 3         3.0
# 10          167 2017-11-30                52         5.2
# 11          168 2017-12-29                52         5.2
# 12          273 2016-01-29                 4         4.0
# 13          274 2016-02-29                 4         4.0
# 14          316 2016-03-31                 7         7.0
# ...

# %%
Y=df['Dowgrade ']

# %%
Y.value_counts()
# Out:
# 0    152259
# 1      2693
# Name: Dowgrade , dtype: int64

# %%
count_0 = len(df[df['Dowgrade ']==0])
count_1 = len([df['Dowgrade ']==1])
pct_of_0 = count_0/(count_0+count_1)
print("percentage of no downgrade is", pct_of_0*100)
pct_of_1 = count_1/(count_0+count_1)
print("percentage of downgrade is", pct_of_1*100)
# Out:
# percentage of no downgrade is 99.99934322868778
# percentage of downgrade is 0.0006567713122290818

# %%
sns.set(style="darkgrid")

# %%
sns.countplot(x='Dowgrade ',data=df)
plt.title('Counts of Obligor Rate Downgrades')
plt.xlabel('Downgrade')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')
